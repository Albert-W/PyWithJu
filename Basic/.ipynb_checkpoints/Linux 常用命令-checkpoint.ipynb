# %% [markdown]
# ## 基本命令

# %%
cd /home/yichang

# %%
ls -lh
# Out:
# 总用量 5.0M
# drwxr-xr-x 1 root    root     512 6月   1 17:50 data
# drwxrwxr-x 1 yichang yichang  512 7月  15 09:50 libiconv-1.16
# -rw-rw-rw- 1 yichang yichang 5.0M 4月  26 20:37 libiconv-1.16.tar.gz
# -rw-rw-rw- 1 yichang yichang   72 6月  18 18:11 未命名.ipynb

# %%
ll # ls -l
# Out:
# 总用量 5096
# drwxr-xr-x 1 yichang yichang     512 7月  18 16:02 ./
# drwxr-xr-x 1 root    root        512 4月   9 15:38 ../
# -rw------- 1 yichang yichang   22563 7月  18 12:32 .bash_history
# -rw-r--r-- 1 yichang yichang     220 2月   3 14:12 .bash_logout
# -rw-r--r-- 1 yichang yichang    4497 5月  17 12:25 .bashrc
# drwxrwxrwx 1 yichang yichang     512 3月  22 17:01 .bundle/
# drwx------ 1 yichang yichang     512 7月  11 14:43 .cache/
# drwxrwsr-x 1 yichang yichang     512 5月  13 20:59 .conda/
# -rw-rw-rw- 1 yichang yichang       0 7月  15 09:44 .condarc
# drwx------ 1 yichang yichang     512 7月  15 16:39 .config/
# drwxr-xr-x 1 root    root        512 6月   1 17:50 data/
# drwxrwxrwx 1 yichang yichang     512 3月  22 16:38 .gem/
# -rw-rw-rw- 1 yichang yichang      37 5月  14 11:22 .gitconfig
# drwxrwxrwx 1 yichang yichang     512 6月  18 18:11 .ipynb_checkpoints/
# drwxr-xr-x 1 yichang yichang     512 5月  13 21:19 .ipython/
# drwxrwxrwx 1 yichang yichang     512 5月  17 12:56 .jsipfs/
# drwxrwxr-x 1 yichang yichang     512 7月  15 16:40 .jupyter/
# drwxrwxr-x 1 yichang yichang     512 7月  15 09:50 libiconv-1.16/
# -rw-rw-rw- 1 yichang yichang 5166734 4月  26 20:37 libiconv-1.16.tar.gz
# drwxr-xr-x 1 yichang yichang     512 4月   9 15:23 .local/
# drwx------ 1 yichang yichang     512 4月  10 09:28 .mozilla/
# drwxrwxrwx 1 yichang yichang     512 5月  22 15:36 .netease-musicbox/
# drwxrwxrwx 1 yichang yichang     512 6月  18 18:10 .node-gyp/
# drwxr-xr-x 1 yichang root        512 5月  14 11:19 .npm/
# drwxrwxrwx 1 yichang yichang     512 5月  17 12:27 .nvm/
# drwx------ 1 yichang yichang     512 4月   9 12:20 .pki/
# -rw-r--r-- 1 yichang yichang     824 4月   9 21:37 .profile
# drwxrwxr-x 1 yichang yichang     512 7月  11 14:29 .pylint.d/
# -rw------- 1 yichang yichang     158 7月  18 16:02 .python_history
# -rw------- 1 yichang yichang       0 7月  18 12:19 .python_history-01272.tmp
# -rw------- 1 yichang yichang       0 7月  18 12:32 .python_history-01472.tmp
# -rw-r--r-- 1 yichang yichang       0 2月  26 20:39 .sudo_as_admin_successful
# -rw------- 1 yichang yichang    9096 7月  17 14:30 .viminfo
# drwxrwxrwx 1 yichang yichang     512 6月   6 17:14 .vscode-server/
# -rw-rw-rw- 1 yichang yichang     165 5月  31 16:32 .wget-hsts
# -rw-rw-rw- 1 yichang yichang      72 6月  18 18:11 未命名.ipynb

# %%
help ls
# Out:
# bash: help: 没有与 `ls' 匹配的帮助主题。尝试 `help help' 或 `man -k ls' 或 `info ls'。
# : 1

# %%
whereis cd
# Out:
# cd:

# %%
help cd
# Out:
# cd: cd [-L|[-P [-e]] [-@]] [目录]
#     改变 shell 工作目录。
#
#     改变当前目录至 DIR 目录。默认的 DIR 目录是 shell 变量 HOME
#     的值。
#
#     变量 CDPATH 定义了含有 DIR 的目录的搜索路径，其中不同的目录名称由冒号 (:)分隔。
#     一个空的目录名称表示当前目录。如果要切换到的 DIR 由斜杠 (/) 开头，则 CDPATH
#     变量不会被使用。
#
#     如果路径找不到，并且 shell 选项 `cdable_vars' 被设定，则参数词被假定为一个
#     变量名。如果该变量有值，则它的值被当作 DIR 目录。
#
#     选项：
#         -L	强制跟随符号链接: 在处理 `..' 之后解析 DIR 中的符号链接。
#         -P	使用物理目录结构而不跟随符号链接: 在处理 `..' 之前解析 DIR 中的符号链接。
#         -e	如果使用了 -P 参数，但不能成功确定当前工作目录时，返回非零的返回值。
#         -@	在支持拓展属性的系统上，将一个有这些属性的文件当作有文件属性的目录。
#
#     默认情况下跟随符号链接，如同指定 `-L'。
#     `..' 使用移除向前相邻目录名成员直到 DIR 开始或一个斜杠的方式处理。
#
#     退出状态：
#     如果目录改变，或在使用 -P 选项时 $PWD 修改成功时返回 0，否则非零。

# %% [markdown]
# ### 后台操作

# %%
python & # 将python放入后台工作
# Out:
# [1] 1887

# %%
ps
# Out:
# Python 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0] :: Anaconda, Inc. on linux
# Type "help", "copyright", "credits" or "license" for more information.
#   PID TTY          TIME CMD
#  1672 pts/2    00:00:00 bash
#  1887 pts/2    00:00:00 python
#  1888 pts/2    00:00:00 ps
#
# [1]+  已停止               python

# %%
jobs # 查看后台程序
# Out:
# [1]+  已停止               python

# %%
# fg %1 # 把后台程序1 恢复到前台, 进入python shell中

# %%
cat /proc/1887/
# Out:
# cat: /proc/1887/: 不允许的操作
# : 1

# %%
cat /proc/1661/limits # 系统对这个进程作出的限制
# Out:
# Limit                     Soft Limit           Hard Limit           Units
# Max cpu time              unlimited            unlimited            seconds
# Max file size             unlimited            unlimited            bytes
# Max data size             unlimited            unlimited            bytes
# Max stack size            8388608              unlimited            bytes
# Max core file size        0                    unlimited            bytes
# Max resident set          unlimited            unlimited            bytes
# Max processes             8041                 8041                 processes
# Max open files            1024                 4096                 files
# Max locked memory         65536                65536                bytes
# Max address space         unlimited            unlimited            bytes
# Max file locks            unlimited            unlimited            locks
# Max pending signals       8041                 8041                 signals
# Max msgqueue size         819200               819200               bytes
# Max nice priority         40                   40
# Max realtime priority     0                    0
# Max realtime timeout      unlimited            unlimited            us

# %% [markdown]
# 打开文件最大数为1024

# %% [markdown]
# ### Linux文件系统
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 系统管理命令

# %%
du -h --max-depth=1 #查看当前目录下文件夹的大小。
# Out:
# 976K	./.ipynb_checkpoints
# 0	./.vscode
# 0	./3.txt
# 1.8M	.

# %%
du -sh *
# Out:
# 0	2.txt
# 0	3.txt
# 0	ini.txt
# 8.0K	jupyter使用技巧.ipynb
# 168K	Linux 常用命令.ipynb
# 0	test.py
# 28K	基础知识-list-str-tuple-dict.ipynb
# 108K	基础知识-变量等.ipynb
# 40K	基础知识-函数.ipynb
# 8.0K	基础知识-语法.ipynb
# 32K	进阶-对象与类.ipynb
# 8.0K	进阶-模块与包.ipynb
# 380K	进阶-文件.ipynb
# 4.0K	算法小模块.ipynb

# %% [markdown]
# ### 系统信息

# %%
lsb_release -a  #查看版本信息
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 18.04.2 LTS
# Release:	18.04
# Codename:	bionic

# %%
head -n 1 /etc/issue
# Out:
# Ubuntu 18.04.2 LTS \n \l

# %%
uname -a #内核/操作系统/CPU信息
# Out:
# Linux DESKTOP-H5LI4PL 4.4.0-17763-Microsoft #379-Microsoft Wed Mar 06 19:16:00 PST 2019 x86_64 x86_64 x86_64 GNU/Linux

# %%
cat /etc/issue
# Out:
# Ubuntu 18.04.2 LTS \n \l

# %%
cat /proc/version #包含GCC的版本信息
# Out:
# Linux version 4.4.0-17763-Microsoft (Microsoft@Microsoft.com) (gcc version 5.4.0 (GCC) ) #379-Microsoft Wed Mar 06 19:16:00 PST 2019

# %%
cat /proc/cpuinfo  # 查看CPU信息
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 0
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 0
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 1
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 1
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 4
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 2
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 5
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 2
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 6
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 3
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:
#
# processor	: 7
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 142
# model name	: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHz
# stepping	: 10
# microcode	: 0xffffffff
# cpu MHz		: 1801.000
# cache size	: 256 KB
# physical id	: 0
# siblings	: 8
# core id		: 3
# cpu cores	: 4
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 6
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave osxsave avx f16c rdrand
# bogomips	: 3602.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 36 bits physical, 48 bits virtual
# power management:

# %%
hostname
# Out:
# DESKTOP-H5LI4PL

# %%
env # 查看环境变量
# Out:
# CONDA_SHLVL=1
# LC_ALL=zh_CN.UTF-8
# NVM_DIR=/home/yichang/.nvm
# LS_COLORS=rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:
# CONDA_EXE=/usr/local/miniconda3/bin/conda
# HOSTTYPE=x86_64
# LESSCLOSE=/usr/bin/lesspipe %s %s
# LANG=zh_CN.UTF-8
# DISPLAY=:0
# AMD_ENTRYPOINT=vs/server/remoteExtensionHostProcess
# NVM_CD_FLAGS=
# CONDA_PREFIX=/usr/local/miniconda3
# _CE_M=
# APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL=true
# USER=yichang
# PAGER=cat
# JPY_PARENT_PID=1058
# PWD=/home/yichang
# HOME=/home/yichang
# CONDA_PYTHON_EXE=/usr/local/miniconda3/bin/python
# TERM_PROGRAM=vscode
# TERM_PROGRAM_VERSION=1.36.1
# NAME=DESKTOP-H5LI4PL
# XDG_DATA_DIRS=/usr/local/share:/usr/share:/var/lib/snapd/desktop
# _CE_CONDA=
# VSCODE_IPC_HOOK_CLI=/tmp/vscode-ipc-99a121bd-5ac1-40d9-93e4-65564a2263e9.sock
# CONDA_PROMPT_MODIFIER=(base)
# TERM=xterm-256color
# SHELL=bash
# NVM_BIN=/home/yichang/.nvm/versions/node/v12.2.0/bin
# SHLVL=5
# LANGUAGE=zh_CN.UTF-8
# PIPE_LOGGING=true
# LOGNAME=yichang
# PATH=/usr/local/miniconda3/bin:/home/yichang/.vscode-server/bin/2213894ea0415ee8c85c5eea0d0ff81ecc191529/bin:/home/yichang/.local/bin:/home/yichang/.nvm/versions/node/v12.2.0/bin:/usr/local/miniconda3/bin:/usr/local/miniconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/mnt/c/Program Files (x86)/NetSarang/Xshell 6:/mnt/c/Program Files (x86)/Common Files/Oracle/Java/javapath:/mnt/c/Windows/System32:/mnt/c/Windows:/mnt/c/Windows/System32/wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0:/mnt/c/Windows/System32/OpenSSH:/mnt/c/Program Files (x86)/NVIDIA Corporation/PhysX/Common:/mnt/c/Program Files/Git/cmd:/mnt/c/Program Files/Java/jdk1.8.0_201/bin:/mnt/c/Program Files/nodejs:/mnt/c/Users/91991/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/91991/AppData/Local/GitHubDesktop/bin:/mnt/c/Program Files/Microsoft VS Code/bin:/mnt/d/electSoftware/LxRunOffline-v3.3.3:/mnt/c/Users/91991/AppData/Roaming/npm:/snap/bin
# PS1=[PEXP\[\]ECT_PROMPT>
# CONDA_DEFAULT_ENV=base
# LESSOPEN=| /usr/bin/lesspipe %s
# VERBOSE_LOGGING=true
# _=/usr/bin/env
# OLDPWD=/mnt/e/codes/Test/pyDemo/Basic
